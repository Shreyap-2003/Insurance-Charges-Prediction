# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'insurance.ui'
#
# Created by: PyQt5 UI code generator 5.15.7
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


from PyQt5 import QtCore, QtGui, QtWidgets


class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(714, 719)
        Form.setStyleSheet("color:rgb(255, 0, 0);\n"
"font: 75 18pt \"MS Shell Dlg 2\";")
        self.label = QtWidgets.QLabel(Form)
        self.label.setGeometry(QtCore.QRect(80, 20, 581, 71))
        self.label.setStyleSheet("font: 20pt \"MS Shell Dlg 2\";\n"
"text-decoration: underline;")
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(Form)
        self.label_2.setGeometry(QtCore.QRect(60, 140, 91, 31))
        self.label_2.setStyleSheet("color: rgb(0, 0, 255);\n"
"font: 18pt \"MS Shell Dlg 2\";")
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(Form)
        self.label_3.setGeometry(QtCore.QRect(60, 200, 91, 31))
        self.label_3.setStyleSheet("color: rgb(0, 0, 255);\n"
"font: 18pt \"MS Shell Dlg 2\";")
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(Form)
        self.label_4.setGeometry(QtCore.QRect(60, 260, 91, 31))
        self.label_4.setStyleSheet("color: rgb(0, 0, 255);\n"
"font: 18pt \"MS Shell Dlg 2\";")
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(Form)
        self.label_5.setGeometry(QtCore.QRect(60, 320, 161, 31))
        self.label_5.setStyleSheet("color: rgb(0, 0, 255);\n"
"font: 18pt \"MS Shell Dlg 2\";")
        self.label_5.setObjectName("label_5")
        self.label_6 = QtWidgets.QLabel(Form)
        self.label_6.setGeometry(QtCore.QRect(60, 380, 151, 31))
        self.label_6.setStyleSheet("color: rgb(0, 0, 255);\n"
"font: 18pt \"MS Shell Dlg 2\";")
        self.label_6.setObjectName("label_6")
        self.label_7 = QtWidgets.QLabel(Form)
        self.label_7.setGeometry(QtCore.QRect(60, 440, 141, 31))
        self.label_7.setStyleSheet("color: rgb(0, 0, 255);\n"
"font: 18pt \"MS Shell Dlg 2\";")
        self.label_7.setObjectName("label_7")
        self.children = QtWidgets.QLineEdit(Form)
        self.children.setGeometry(QtCore.QRect(230, 320, 121, 41))
        self.children.setStyleSheet("color: rgb(170, 0, 127);")
        self.children.setText("")
        self.children.setObjectName("children")
        self.bmi = QtWidgets.QLineEdit(Form)
        self.bmi.setGeometry(QtCore.QRect(230, 260, 121, 41))
        self.bmi.setStyleSheet("color: rgb(170, 0, 127);")
        self.bmi.setText("")
        self.bmi.setObjectName("bmi")
        self.region = QtWidgets.QLineEdit(Form)
        self.region.setGeometry(QtCore.QRect(230, 440, 121, 41))
        self.region.setStyleSheet("color: rgb(170, 0, 127);")
        self.region.setText("")
        self.region.setObjectName("region")
        self.smoker = QtWidgets.QLineEdit(Form)
        self.smoker.setGeometry(QtCore.QRect(230, 380, 121, 41))
        self.smoker.setStyleSheet("color: rgb(170, 0, 127);")
        self.smoker.setText("")
        self.smoker.setObjectName("smoker")
        self.age = QtWidgets.QLineEdit(Form)
        self.age.setGeometry(QtCore.QRect(230, 140, 121, 41))
        self.age.setStyleSheet("color: rgb(170, 0, 127);")
        self.age.setText("")
        self.age.setObjectName("age")
        self.sex = QtWidgets.QLineEdit(Form)
        self.sex.setGeometry(QtCore.QRect(230, 200, 121, 41))
        self.sex.setStyleSheet("color: rgb(170, 0, 127);")
        self.sex.setText("")
        self.sex.setObjectName("sex")
        self.pushButton_predict = QtWidgets.QPushButton(Form)
        self.pushButton_predict.setGeometry(QtCore.QRect(260, 540, 161, 61))
        self.pushButton_predict.setStyleSheet("color:rgb(170, 85, 0);\n"
"font: 18pt \"MS Shell Dlg 2\";\n"
"background-color: rgb(255, 255, 127);")
        self.pushButton_predict.setObjectName("pushButton_predict")
        self.label_result = QtWidgets.QLabel(Form)
        self.label_result.setGeometry(QtCore.QRect(260, 630, 241, 71))
        self.label_result.setStyleSheet("font: 75 18pt \"MS Shell Dlg 2\";")
        self.label_result.setObjectName("label_result")
        self.pushButton_predict.clicked.connect(self.predict)

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)
    def predict(self):
        age=self.age.text()
        sex=self.sex.text()
        bmi=self.bmi.text()
        children=self.children.text()
        smoker=self.smoker.text()
        region=self.region.text()
        import pandas as pd
        path="C:\\Users\\hp\\Downloads\\2023_CSE_Project\\2023_CSE_Project\\Linear_MultipleRegression\\Insurance\\insurance.csv"
        data=pd.read_csv(path)
        #print(data)
        #print(data.info())
        #print(data.isnull().sum())

        import sklearn
        from sklearn.preprocessing import LabelEncoder
        le_Gender=LabelEncoder()
        data['sex']=le_Gender.fit_transform(data['sex'])
        
        
        import sklearn
        from sklearn.preprocessing import LabelEncoder
        le_Gender=LabelEncoder()
        data['smoker']=le_Gender.fit_transform(data['smoker'])
        print(data)
        
        data["region"] = data["region"].map({"southwest": 0, "southeast": 1, "northwest": 2, "northeast": 3,"US":4})

        inputs=data.drop(['charges'],axis=1)
        output=data.drop(['age','sex','bmi','children','smoker','region'],axis=1)
        #print(inputs)
        #print(output)

        import sklearn
        import math
        from sklearn import linear_model
        model=linear_model.LinearRegression()
        model.fit(inputs,output)

        res=model.predict([[int(age),int(sex),float(bmi),int(children),int(smoker),int(region)]])
        print(res)
        
        acc=model.score(inputs,output)
        print(acc*100)
        self.label_result.setText(str(res))

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        self.label.setText(_translate("Form", "PREDICTION OF INSURANCE CHARGES"))
        self.label_2.setText(_translate("Form", "AGE :"))
        self.label_3.setText(_translate("Form", "SEX :"))
        self.label_4.setText(_translate("Form", "BMI :"))
        self.label_5.setText(_translate("Form", "CHILDERN :"))
        self.label_6.setText(_translate("Form", "SMOKER :"))
        self.label_7.setText(_translate("Form", "REGION :"))
        self.pushButton_predict.setText(_translate("Form", "Predict"))
        self.label_result.setText(_translate("Form", "Result"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
# Out:
#       age  sex     bmi  children  smoker     region      charges
# 0      19    0  27.900         0       1  southwest  16884.92400
# 1      18    1  33.770         1       0  southeast   1725.55230
# 2      28    1  33.000         3       0  southeast   4449.46200
# 3      33    1  22.705         0       0  northwest  21984.47061
# 4      32    1  28.880         0       0  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 1333   50    1  30.970         3       0  northwest  10600.54830
# 1334   18    0  31.920         0       0  northeast   2205.98080
# 1335   18    0  36.850         0       0  southeast   1629.83350
# 1336   21    0  25.800         0       0  southwest   2007.94500
# 1337   61    0  29.070         0       1  northwest  29141.36030
#
# [1338 rows x 7 columns]
# ...
